# %%
! pip install spotipy --upgrade

# %% [markdown]
# # 0. Login the Spotify Client

# %%
import os
with open("spotify-secret.txt", "r") as f:
    os.environ["SPOTIPY_CLIENT_ID"] = f.readline().strip()
    os.environ["SPOTIPY_CLIENT_SECRET"] = f.readline().strip()

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

api = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

# %% [markdown]
# # 1. Search the shows
# Search the shows by specifying the topic and keep all the English shows' uri in `topic_info` varibale.

# %%
topics = ["machine learning", "cooking", "crime", "politics", "kid",
          "comedy", "sport", "culture", "lifestyle", "business"]

# %% [markdown]
# ## 1.1 Utility functions

# %%
def write_file(log, file):
    '''
        Write the logging file
    '''
    with open(file+".txt", "a") as f:
        f.write(log.strip()+'\n')

# %%
def check_language(show, topic):
    '''
        Keep only English shows
    '''
    log = f"{show['id']} , {show['name']} , {show['languages']} , {topic}"
    if any(["en" in lang for lang in show['languages']]):
        write_file(log, "included")
        return True
    else:
        write_file(log, "excluded")
        return False

def check_duplicate(x: list):
    '''
        Check if x has duplicated value.
    '''
    return len(set(x)) == len(x)

def window_search(topic, offset, limit):
    '''
        Searching by using Spotify API
        while keep the number of API calls as low as possible
    '''
    results = api.search(topic, type="show", market="TH", limit=limit, offset=offset)

    name, id, uri = [], [] , []
    notEN = 0

    for show in results['shows']['items']:
        if show['id'] in id:
            print(f"{show['id']} duplicated .. skipped")
            continue
        if check_language(show, topic):
            name.append(show['name'])
            id.append(show['id'])
            uri.append(show['uri'])
        else:
            notEN += 1
            
    return notEN, name, id, uri

# %% [markdown]
# ## 1.2 Searching the shows in each topic

# %%
from collections import defaultdict
import time

topics_info = {}
N_SHOWS = 50
n_requests = 0

for topic in topics:
    print(f"\nQuerying {topic} ...")

    show_info = defaultdict(lambda: list())
    offset = 0
    limit = N_SHOWS

    while len(show_info['id']) < N_SHOWS:

        time.sleep(0.5)
        notEN, name, id, uri = window_search(topic, 
                                             offset = offset,
                                             limit = limit)
        n_requests += limit
        show_info['name']+=name
        show_info['id']+=id
        show_info['uri']+=uri

        offset += N_SHOWS
        limit = notEN + 1
    
    topics_info[topic] = dict(show_info)
    print(f"\t {topic} has {len(show_info['id'])} shows")
# Out:
# Querying machine learning ...
# 	 machine learning has 50 shows
#
# Querying cooking ...
# 	 cooking has 52 shows
#
# Querying crime ...
# 	 crime has 52 shows
#
# Querying politics ...
# 	 politics has 53 shows
#
# Querying kid ...
# 	 kid has 50 shows
#
# Querying comedy ...
# 	 comedy has 51 shows
#
# Querying sport ...
# 	 sport has 52 shows
#
# Querying culture ...
# 	 culture has 52 shows
#
# Querying lifestyle ...
# 	 lifestyle has 53 shows
#
# Querying business ...
# 	 business has 52 shows

# %%
print(f'total requests : {n_requests}')
# Out:
# total requests : 950

# %%
for topic in topics_info.keys():
    try:
        assert check_duplicate(topics_info[topic]["id"])
    except AssertionError:
        print(f'[{topic} has duplicates]')
# Out:
# [politics has duplicates]
# [sport has duplicates]
# [culture has duplicates]
# [business has duplicates]

# %% [markdown]
# ## 1.3 Export shows' info

# %%
import pandas as pd

df = pd.read_csv("included.txt", sep=" , ", header=None, engine="python")
df.columns=["id","name","language","label"]

# %%
df
# Out:
#                          id  ...             label
# 0    02e6PZeIOdpmBGT9THuzwR  ...  machine learning
# 1    5M9yZpSyF1jc7uFp2MlhP9  ...  machine learning
# 2    1LaCr5TFAgYPK5qHjP3XDp  ...  machine learning
# 3    7o9r3fFig3MhTJwehXDbXm  ...  machine learning
# 4    6g03vdHyFfYWYdRAPKfdQM  ...  machine learning
# ..                      ...  ...               ...
# 512  1TeUxfqH1803TE9SZt6VIi  ...          business
# 513  05sB5LFthkIXOfU6uYNe9A  ...          business
# 514  7KCg1Xg0AG82jmqqBDurEx  ...          business
# 515  29QJfd80NNfZtMon3SogZZ  ...          business
# 516  4yjqr4a5tBNMzfg4DzKzmq  ...          business
#
# [517 rows x 4 columns]

# %% [markdown]
# # 2. Query 50 episodes of each show

# %%
from urllib3.exceptions import MaxRetryError

total_df = pd.DataFrame(columns = ['ep_id','ep_name','show_name','description','label'])

# %%
for index, row in df.iterrows():
    print(f"Querying ... show: {row['name']}")

    try:
        result = api.show_episodes(row['id'], market="TH", limit=50)
    except (
        MaxRetryError,
        spotipy.client.SpotifyException) as e:
        print(e)
        write_file(f"{row['id']}, {row['name']}, {row['label']}", "failed_ep_query")
        print(f"skipped : {row['id']}, {row['name']}")

    new_row = defaultdict(lambda: list())
    c = 0
    for ep in result['items']:
        new_row['ep_id'].append(ep['id'])
        new_row['ep_name'].append(ep['name'])
        new_row['description'].append(ep['description'])
        new_row['label'].append(row['label'])
        new_row['show_name'].append(row['name'])
        c+=1

    print(f"\t\tcollected {c} episodes")
    total_df = total_df.append(
                    pd.DataFrame(dict(new_row))
                )
    
    time.sleep(0.5)
# Out:
# Querying ... show: Machine Learning Street Talk
# 		collected 50 episodes
# Querying ... show: Machine Learning Guide
# 		collected 30 episodes
# Querying ... show: Practical AI: Machine Learning, Data Science
# 		collected 50 episodes
# Querying ... show: Gradient Dissent - A Machine Learning Podcast by W&B
# 		collected 50 episodes
# Querying ... show: Adventures in Machine Learning
# 		collected 50 episodes
# Querying ... show: The Medicine & Machine Learning Podcast (MaML)
# 		collected 12 episodes
# Querying ... show: Cocktail Time Machine
# 		collected 46 episodes
# Querying ... show: Learning Machine: The Uncertain Future of Education
# 		collected 5 episodes
# Querying ... show: Machine Learning Africa
# 		collected 14 episodes
# Querying ... show: The Interpretable Machine Learning Podcast
# 		collected 2 episodes
# Querying ... show: Love Machine with James Preece
# 		collected 50 episodes
# Querying ... show: Unstoppable Recording Machine Podcast
# 		collected 50 episodes
# Querying ... show: Neura Pod: Learning about Neuralink
# 		collected 49 episodes
# Querying ... show: Computomics: Discussions On Machine Learning Algorithms For Plant Breeding Challenges
# 		collected 27 episodes
# Querying ... show: The Greatness Machine
# 		collected 33 episodes
# Querying ... show: Morning Marketing Machine
# 		collected 50 episodes
# Querying ... show: The Wise Machine
# 		collected 2 episodes
# Querying ... show: The Label Machine Podcast
# 		collected 16 episodes
# Querying ... show: Hot Tub Cult Machine
# 		collected 10 episodes
# Querying ... show: Learn With Avthar
# 		collected 50 episodes
# Querying ... show: Machine Learning 101 For Cricket Fanatics
# 		collected 1 episodes
# Querying ... show: Masteraudio: Machine Learning
# 		collected 1 episodes
# Querying ... show: The TWIML AI Podcast (formerly This Week in Machine Learning & Artificial Intelligence)
# 		collected 50 episodes
# Querying ... show: Secrets & Lies: Humanity + the Machine
# 		collected 6 episodes
# Querying ... show: Machine Learning
# 		collected 1 episodes
# Querying ... show: Machine Learning with SAP S/4HANA
# 		collected 15 episodes
# Querying ... show: Learning Machine
# 		collected 4 episodes
# Querying ... show: Reinforcement Learning
# 		collected 1 episodes
# Querying ... show: A Beginners Guide to Understand Machine Learning
# 		collected 1 episodes
# Querying ... show: Canna Machine CBD and Cannabis Industry Podcast
# 		collected 13 episodes
# Querying ... show: ACM ByteCast
# 		collected 18 episodes
# Querying ... show: Learn Programming With eduAlgo
# 		collected 3 episodes
# Querying ... show: Machine Learning with Coffee
# 		collected 20 episodes
# Querying ... show: Building the Machine
# 		collected 4 episodes
# Querying ... show: Clean Green Music Machine: Turn It Up!
# 		collected 10 episodes
# Querying ... show: Machine Gun
# 		collected 50 episodes
# Querying ... show: The Shteig Machine
# 		collected 3 episodes
# Querying ... show: Machine Learning Bytes
# 		collected 6 episodes
# Querying ... show: Box Office Time Machine
# 		collected 46 episodes
# Querying ... show: Bleav in Sports Time Machine
# 		collected 35 episodes
# Querying ... show: Empathy Machine
# 		collected 17 episodes
# Querying ... show: The Dental Machine Audio Blog
# 		collected 28 episodes
# Querying ... show: Machines vs Mankind
# 		collected 2 episodes
# Querying ... show: Into the Machine
# 		collected 1 episodes
# Querying ... show: The Joy of Marketing
# 		collected 14 episodes
# Querying ... show: The Infinite Meme Machine: A Destiny Podcast
# 		collected 13 episodes
# Querying ... show: The German ww1 war machine
# 		collected 1 episodes
# Querying ... show: Social Prachar | Exclusive Podcast Learning's
# 		collected 19 episodes
# Querying ... show: Marketing & The Machine
# 		collected 4 episodes
# Querying ... show: Your Data Teacher Podcast
# 		collected 7 episodes
# Querying ... show: Cooking Hot Dogs
# 		collected 10 episodes
# Querying ... show: Home Cooking
# 		collected 16 episodes
# Querying ... show: Hoo Cook Podcast
# 		collected 10 episodes
# Querying ... show: Gray Cook Radio
# 		collected 15 episodes
# Querying ... show: samantha cooking
# 		collected 10 episodes
# Querying ... show: Cooksey and The Coach
# 		collected 39 episodes
# Querying ... show: Nancy Ballesteros Spanish Cook, The Live Cooking Academy
# 		collected 9 episodes
# Querying ... show: Cooking Issues with Dave Arnold
# 		collected 12 episodes
# Querying ... show: Cooking Sustainably Podcast
# 		collected 7 episodes
# Querying ... show: The Todd Cook Show
# 		collected 13 episodes
# Querying ... show: The Cooke Collective Podcast
# 		collected 29 episodes
# Querying ... show: Chef Cardinale Cooking Show
# 		collected 7 episodes
# Querying ... show: Jill Blakeway's Grow Cook Heal
# 		collected 15 episodes
# Querying ... show: The Cookie Jar Golf Podcast
# 		collected 50 episodes
# Querying ... show: Italian Cook Book, The by Maria Gentile
# 		collected 11 episodes
# Querying ... show: CookieJar: The Queer Podcast
# 		collected 11 episodes
# Querying ... show: Everything That Matters: In Life, Business, Parenting, Cooking, and Kitchen Table Politics
# 		collected 15 episodes
# Querying ... show: That's Cooked Podcast
# 		collected 13 episodes
# Querying ... show: It's Just a Cookie
# 		collected 15 episodes
# Querying ... show: The Quick Cook - Anu Rao
# 		collected 5 episodes
# Querying ... show: Cooking Up Consciousness Podcast
# 		collected 13 episodes
# Querying ... show: COOKIE & CREAM PODCAST
# 		collected 27 episodes
# Querying ... show: Misfortune Cookies
# 		collected 16 episodes
# Querying ... show: cookout legs
# 		collected 6 episodes
# Querying ... show: Captain and Cook Pod
# 		collected 28 episodes
# Querying ... show: Cookin Around
# 		collected 4 episodes
# Querying ... show: The Cookie Cutter Podcast
# 		collected 8 episodes
# Querying ... show: Supe's On! With Dr. Steven Cook
# 		collected 2 episodes
# Querying ... show: Cookies and Cafe
# 		collected 2 episodes
# Querying ... show: Cookie French
# 		collected 9 episodes
# Querying ... show: Cookie Jar Confessionals
# 		collected 7 episodes
# Querying ... show: The Post-Race Cookie Cast
# 		collected 12 episodes
# Querying ... show: The Hidden Cookies Podcast
# 		collected 10 episodes
# Querying ... show: Unlimited Possibilities with Barbara Cook
# 		collected 10 episodes
# Querying ... show: Tasty Pages: A Podcast From Cooking The Books
# 		collected 46 episodes
# Querying ... show: Craftsmen Cooking
# 		collected 21 episodes
# Querying ... show: BEING with Patrick Cooke
# 		collected 42 episodes
# Querying ... show: This Goose Is Cooked
# 		collected 42 episodes
# Querying ... show: Cooking Up Stupid
# 		collected 14 episodes
# Querying ... show: The Cookoo Podcast
# 		collected 8 episodes
# Querying ... show: What's Cookin' in Sports Podcast
# 		collected 27 episodes
# Querying ... show: Jessica Cooke's #FEELGOOD Podcast
# 		collected 24 episodes
# Querying ... show: Cookie Pocket (This Podcast Is About Film)
# 		collected 48 episodes
# Querying ... show: Planned, Prepped, and Productive: Real Food Cooking for Busy Moms
# 		collected 50 episodes
# Querying ... show: Cooking With Grief
# 		collected 50 episodes
# Querying ... show: The Power of a Cookie
# 		collected 30 episodes
# Querying ... show: Gettin Cooked
# 		collected 33 episodes
# Querying ... show: On My Day with Nat Cook
# 		collected 35 episodes
# Querying ... show: Big Rap Cookbook
# 		collected 17 episodes
# Querying ... show: Cookies and Candles
# 		collected 3 episodes
# Querying ... show: HIGHly Inappropriate Hosted By Cook Simmons
# 		collected 7 episodes
# Querying ... show: The Paul Cook Talks Podcast
# 		collected 5 episodes
# Querying ... show: Crime Junkie
# 		collected 50 episodes
# Querying ... show: Casefile True Crime
# 		collected 50 episodes
# Querying ... show: Unsolved Murders: True Crime Stories
# 		collected 50 episodes
# Querying ... show: Solved Murders: True Crime Mysteries
# 		collected 50 episodes
# Querying ... show: Morbid: A True Crime Podcast
# 		collected 50 episodes
# Querying ... show: Crime Show
# 		collected 11 episodes
# Querying ... show: Crimes of Passion
# 		collected 50 episodes
# Querying ... show: Wine & Crime
# 		collected 50 episodes
# Querying ... show: Criminal
# 		collected 50 episodes
# Querying ... show: Sistas Who Kill: A True Crime Podcast
# 		collected 22 episodes
# Querying ... show: Game of Crimes
# 		collected 10 episodes
# Querying ... show: True Crime Kent
# 		collected 21 episodes
# Querying ... show: Black Girl Gone: A True Crime Podcast
# 		collected 25 episodes
# Querying ... show: The Wine & Crime
# 		collected 10 episodes
# Querying ... show: Crime Victoria
# 		collected 10 episodes
# Querying ... show: True Crime Arizona
# 		collected 28 episodes
# Querying ... show: Secret Crime Show
# 		collected 10 episodes
# Querying ... show: Anatomy Crime
# 		collected 10 episodes
# Querying ... show: The Hollywood Crime Scene
# 		collected 10 episodes
# Querying ... show: Truer Crime
# 		collected 11 episodes
# Querying ... show: As The Crime Turns: The True Crime Podcast
# 		collected 15 episodes
# Querying ... show: Crimepedia
# 		collected 50 episodes
# Querying ... show: Our Crime Official
# 		collected 10 episodes
# Querying ... show: Crime and Crime Again
# 		collected 26 episodes
# Querying ... show: The Society Crime
# 		collected 10 episodes
# Querying ... show: True Crime Podcast
# 		collected 12 episodes
# Querying ... show: TRUE CRIME LOSER Podcast
# 		collected 50 episodes
# Querying ... show: Carolina Crimes
# 		collected 29 episodes
# Querying ... show: Shaun Attwood's True Crime Podcast
# 		collected 50 episodes
# Querying ... show: Crime on the Couch
# 		collected 50 episodes
# Querying ... show: Crime Curious
# 		collected 50 episodes
# Querying ... show: True Crime All The Time
# 		collected 50 episodes
# Querying ... show: Mama Mystery - A True Crime Podcast
# 		collected 50 episodes
# Querying ... show: True Crime Out Loud
# 		collected 37 episodes
# Querying ... show: Morbid: A True Crime True Official
# 		collected 10 episodes
# Querying ... show: Four Corners Crime Cast
# 		collected 50 episodes
# Querying ... show: Crochet & Crime
# 		collected 31 episodes
# Querying ... show: True Love, Truer Crimes
# 		collected 19 episodes
# Querying ... show: Campus Crime Chronicles
# 		collected 14 episodes
# Querying ... show: Borderland Crimes
# 		collected 11 episodes
# Querying ... show: Fatal Crime Confessions
# 		collected 50 episodes
# Querying ... show: True Crime & Knit
# 		collected 8 episodes
# Querying ... show: UK True Crime Podcast
# 		collected 50 episodes
# Querying ... show: New Books in Terrorism and Organized Crime
# 		collected 10 episodes
# Querying ... show: LAGIM: A Filipino True Crime Podcast
# 		collected 23 episodes
# Querying ... show: Clueston: True Crime in Houston, Texas
# 		collected 45 episodes
# Querying ... show: The Lost Crimes Library
# 		collected 26 episodes
# Querying ... show: Unraveled: A True Crime Podcast
# 		collected 16 episodes
# Querying ... show: AUK News Crime
# 		collected 10 episodes
# Querying ... show: Crime With Chrissy | Murder With Missy
# 		collected 2 episodes
# Querying ... show: True Crime Garage
# 		collected 50 episodes
# Querying ... show: Conspiracy, Not the Crime
# 		collected 10 episodes
# Querying ... show: Politics Weekly
# 		collected 50 episodes
# Querying ... show: The NPR Politics Podcast
# 		collected 50 episodes
# Querying ... show: The Political Party
# 		collected 50 episodes
# Querying ... show: PODKAS: Conversations on Philippine History, Politics, & Society
# 		collected 42 episodes
# Querying ... show: Belief Political
# 		collected 10 episodes
# Querying ... show: Radius News Politics
# 		collected 10 episodes
# Querying ... show: Our Politic Enemy
# 		collected 10 episodes
# Querying ... show: The Political Logic
# 		collected 10 episodes
# Querying ... show: Politic Cyrcus Club
# 		collected 10 episodes
# Querying ... show: Be Politic Show
# 		collected 10 episodes
# Querying ... show: Your Politic Mind
# 		collected 10 episodes
# Querying ... show: The Political Life
# 		collected 10 episodes
# Querying ... show: Street Politicians
# 		collected 50 episodes
# Querying ... show: Hiraeth - Welsh Politics
# 		collected 50 episodes
# Querying ... show: Reel Politik Podcast
# 		collected 50 episodes
# Querying ... show: Not Always Polite
# 		collected 43 episodes
# Querying ... show: The Politicians
# 		collected 10 episodes
# Querying ... show: The PPR Politics Official
# 		collected 10 episodes
# Querying ... show: Nigeria Politics Weekly
# 		collected 50 episodes
# Querying ... show: No Politics
# 		collected 8 episodes
# Querying ... show: Utah Politics
# 		collected 50 episodes
# Querying ... show: Pint of Politics
# 		collected 36 episodes
# Querying ... show: Political Economy Theory by Daoudi
# 		collected 2 episodes
# Querying ... show: Pro Politics with Zac McCrary
# 		collected 26 episodes
# Querying ... show: LEONARD: Political Prisoner
# 		collected 11 episodes
# Querying ... show: Political Audio
# 		collected 15 episodes
# Querying ... show: Oratoria política aplicada a campañas electorales
# 		collected 50 episodes
# Querying ... show: Pint of Politics
# 		collected 36 episodes
# Querying ... show: Political Economy Theory by Daoudi
# 		collected 2 episodes
# Querying ... show: Pro Politics with Zac McCrary
# 		collected 26 episodes
# Querying ... show: LEONARD: Political Prisoner
# 		collected 11 episodes
# Querying ... show: Political Audio
# 		collected 15 episodes
# Querying ... show: The Element Podcast | Hunting, Public Land, Tactics, Whitetail Deer, Wildlife, Travel, Conservation, Politics and more.
# 		collected 50 episodes
# Querying ... show: Rendering Unconscious Podcast: Psychoanalysis, Art, Politics, Culture
# 		collected 50 episodes
# Querying ... show: The Badlands Politics & Philosophy Podcast
# 		collected 50 episodes
# Querying ... show: Politikpratarna
# 		collected 36 episodes
# Querying ... show: Weekly Political Pep Talks
# 		collected 4 episodes
# Querying ... show: Playground Politics
# 		collected 31 episodes
# Querying ... show: Política sin letra chica, el podcast de Contexto Factual.
# 		collected 36 episodes
# Querying ... show: Revise - A Level Political Studies Revision
# 		collected 11 episodes
# Querying ... show: Global Politics & Culture (formerly Independent Thought & Freedom)
# 		collected 50 episodes
# Querying ... show: PBS NewsHour - Politics Monday
# 		collected 25 episodes
# Querying ... show: Polite Bitches
# 		collected 8 episodes
# Querying ... show: Do Politics Better Podcast
# 		collected 23 episodes
# Querying ... show: The ABCs of Green Politics
# 		collected 11 episodes
# Querying ... show: The Peachy Politics Podcast
# 		collected 10 episodes
# Querying ... show: Best Coast Political Podcast
# 		collected 21 episodes
# Querying ... show: Politicology
# 		collected 50 episodes
# Querying ... show: Liverpool Politics Hour
# 		collected 50 episodes
# Querying ... show: Polititeen
# 		collected 50 episodes
# Querying ... show: The Way of Improvement Leads Home: American History, Religion, Politics, and Academic life.
# 		collected 50 episodes
# Querying ... show: Political Tales
# 		collected 3 episodes
# Querying ... show: The Other Side: MS Todays Political Podcast
# 		collected 50 episodes
# Querying ... show: Disney Stories For Kids
# 		collected 50 episodes
# Querying ... show: English For Kids
# 		collected 42 episodes
# Querying ... show: Sleep Tight Stories - Bedtime Stories for Kids
# 		collected 50 episodes
# Querying ... show: Kid's Bed Time Stories
# 		collected 45 episodes
# Querying ... show: Kids Short Stories
# 		collected 50 episodes
# Querying ... show: Sleep Tight Relax - Helping kids become calm at bedtime
# 		collected 50 episodes
# Querying ... show: English Kids Story with Katrina
# 		collected 50 episodes
# Querying ... show: By Kids, For Kids Story Time
# 		collected 50 episodes
# Querying ... show: Kid Stories
# 		collected 50 episodes
# Querying ... show: Fun Fables: Bedtime Stories for Kids
# 		collected 14 episodes
# Querying ... show: The Luke Kidgell Hour
# 		collected 50 episodes
# Querying ... show: Honeybee Kids - Bedtime Stories
# 		collected 50 episodes
# Querying ... show: Kids Zone
# 		collected 10 episodes
# Querying ... show: 4 kids by kids
# 		collected 50 episodes
# Querying ... show: You're Kidding, Right?
# 		collected 50 episodes
# Querying ... show: Have Kids, They Said…
# 		collected 45 episodes
# Querying ... show: Greeking Out from National Geographic Kids
# 		collected 26 episodes
# Querying ... show: Kid Contractor Podcast with Caleb Auman
# 		collected 50 episodes
# Querying ... show: Great Kids' Stories
# 		collected 10 episodes
# Querying ... show: Story Quest – Stories for Kids
# 		collected 50 episodes
# Querying ... show: Stay Together for the Kids
# 		collected 10 episodes
# Querying ... show: Top 100 bedtime stories for kids
# 		collected 13 episodes
# Querying ... show: History Storytime - For Kids
# 		collected 50 episodes
# Querying ... show: Chitas for Kids
# 		collected 50 episodes
# Querying ... show: Maked Up Stories: Imaginative Kids Stories
# 		collected 50 episodes
# Querying ... show: Big Life Kids Podcast
# 		collected 50 episodes
# Querying ... show: Professor Hallux: The Human Body Podcast for Kids
# 		collected 50 episodes
# Querying ... show: Story time for Kids
# 		collected 50 episodes
# Querying ... show: Science Adventure Stories For Kids
# 		collected 15 episodes
# Querying ... show: Storynory - Audio Stories For Kids
# 		collected 50 episodes
# Querying ... show: Story With Anvi, Stories For Kids In Hindi
# 		collected 50 episodes
# Querying ... show: Podar Jumbo Kids Podcasts
# 		collected 50 episodes
# Querying ... show: Kiddush Club - The Podcast
# 		collected 15 episodes
# Querying ... show: Kidible the read aloud for kids
# 		collected 18 episodes
# Querying ... show: Bedtime History: Inspirational Stories for Kids and Families
# 		collected 50 episodes
# Querying ... show: Classic English Stories For Kids
# 		collected 28 episodes
# Querying ... show: Kids For Laugh
# 		collected 10 episodes
# Querying ... show: KOllOK 1991 - Kids On Bikes TTRPG
# 		collected 50 episodes
# Querying ... show: Storytime With Savannah / Kids Stories
# 		collected 50 episodes
# Querying ... show: Bible Stories For Kids
# 		collected 9 episodes
# Querying ... show: Keys For Kids Ministries Podcast
# 		collected 7 episodes
# Querying ... show: Kidnapped: A God Story
# 		collected 8 episodes
# Querying ... show: The Alien Adventures of Finn Caspian: Science Fiction for Kids
# 		collected 50 episodes
# Querying ... show: Little Stories for Tiny People: Anytime and bedtime stories for kids
# 		collected 50 episodes
# Querying ... show: What If World - Stories for Kids
# 		collected 50 episodes
# Querying ... show: Abide Kids Bedtime Stories
# 		collected 21 episodes
# Querying ... show: The Cisco Kid - OTRWesterns.com
# 		collected 50 episodes
# Querying ... show: Karate Kid Minute
# 		collected 50 episodes
# Querying ... show: Meddling Kids
# 		collected 8 episodes
# Querying ... show: Kareena's Chemistry for Kids
# 		collected 50 episodes
# Querying ... show: Comedy Bang Bang: The Podcast
# 		collected 50 episodes
# Querying ... show: Friday Night Comedy from BBC Radio 4
# 		collected 50 episodes
# Querying ... show: Stand Up Comedy Compilation
# 		collected 3 episodes
# Querying ... show: Comedy Gold Minds with Kevin Hart
# 		collected 28 episodes
# Querying ... show: Comedy of the Week
# 		collected 4 episodes
# Querying ... show: Talks Enjoy Comedy
# 		collected 10 episodes
# Querying ... show: British Comedy Reserve
# 		collected 9 episodes
# Querying ... show: Comedy Gold Minds
# 		collected 10 episodes
# Querying ... show: HILAKBOT TV's PINOY HORROR STORIES | The Podcast
# 		collected 50 episodes
# Querying ... show: The Capital Comedy
# 		collected 10 episodes
# Querying ... show: Filipino Vines
# 		collected 13 episodes
# Querying ... show: The Laugh Comedy
# 		collected 10 episodes
# Querying ... show: Comedy Mistake Laugh
# 		collected 10 episodes
# Querying ... show: Comedy Edition
# 		collected 10 episodes
# Querying ... show: That Comedy Podcast
# 		collected 10 episodes
# Querying ... show: Comedians on South High
# 		collected 47 episodes
# Querying ... show: Comedy Latvia: Podkāsts
# 		collected 13 episodes
# Querying ... show: The Small Comedy
# 		collected 10 episodes
# Querying ... show: Warnet Comedy
# 		collected 10 episodes
# Querying ... show: KunstlerCast - Suburban Sprawl: A Tragic Comedy
# 		collected 50 episodes
# Querying ... show: Comedy Star Podcast
# 		collected 10 episodes
# Querying ... show: Giggle Beats Comedy
# 		collected 10 episodes
# Querying ... show: Daily Comedy News: a podcast about comedians
# 		collected 50 episodes
# Querying ... show: Comedy Album Book Club
# 		collected 50 episodes
# Querying ... show: The Comedy Arcade
# 		collected 38 episodes
# Querying ... show: Comedy Fight Club
# 		collected 33 episodes
# Querying ... show: Plane Comedy
# 		collected 13 episodes
# Querying ... show: Champagne Comedy Podcast
# 		collected 49 episodes
# Querying ... show: The Comedy Fix
# 		collected 49 episodes
# Querying ... show: A Comedy Advice Podcast
# 		collected 50 episodes
# Querying ... show: "The Right Show Podcast" w/ Comedian K-von
# 		collected 21 episodes
# Querying ... show: The Comedian's Comedian Podcast
# 		collected 50 episodes
# Querying ... show: Geezer Gus Presents™ - Classic Radio Shows / Classic Comedy Shows
# 		collected 50 episodes
# Querying ... show: Improv Comedy Connection
# 		collected 44 episodes
# Querying ... show: The Comedy Cellar: Live from the Table
# 		collected 50 episodes
# Querying ... show: Cake Block - A Sketch Comedy Podcast
# 		collected 23 episodes
# Querying ... show: Disc Golf Comedy
# 		collected 8 episodes
# Querying ... show: A Comedy of Eras
# 		collected 11 episodes
# Querying ... show: Comedians Playing Fantasy Premier League
# 		collected 1 episodes
# Querying ... show: Wireless Theatre Comedy
# 		collected 50 episodes
# Querying ... show: Comedy Old Time Radio
# 		collected 10 episodes
# Querying ... show: I'm sorry I haven't a clue comedy show
# 		collected 1 episodes
# Querying ... show: The Sheep Laughs Comedy Show
# 		collected 50 episodes
# Querying ... show: Bourbon and Brothers Comedy Podcast
# 		collected 23 episodes
# Querying ... show: Kids comedy
# 		collected 1 episodes
# Querying ... show: Release The Clowns Sketch Comedy Podcast
# 		collected 50 episodes
# Querying ... show: Bobby’s Comedy Corner
# 		collected 12 episodes
# Querying ... show: The Kicker Podcast: A Sports-Comedy Show
# 		collected 50 episodes
# Querying ... show: Comedy Factory from CBC Radio
# 		collected 21 episodes
# Querying ... show: Ian Talks Comedy
# 		collected 50 episodes
# Querying ... show: Countdown To Relapse: Addiction, Recovery and Dark Comedy
# 		collected 13 episodes
# Querying ... show: Alfa Sport
# 		collected 10 episodes
# Querying ... show: sport-related concussion
# 		collected 10 episodes
# Querying ... show: The Sound Sport
# 		collected 10 episodes
# Querying ... show: Extra/ordinary Sports Podcast
# 		collected 20 episodes
# Querying ... show: Sport News Syndicate
# 		collected 10 episodes
# Querying ... show: Next Sport Network
# 		collected 10 episodes
# Querying ... show: Houndsman XP - Sportsmen's Nation
# 		collected 50 episodes
# Querying ... show: Achieve a Balanced Life, with Sports
# 		collected 10 episodes
# Querying ... show: Sports Mind Show
# 		collected 10 episodes
# Querying ... show: The Sporting Rumble
# 		collected 40 episodes
# Querying ... show: On The Sporting Couch
# 		collected 10 episodes
# Querying ... show: Sport Taste Talk
# 		collected 10 episodes
# Querying ... show: On The Sporting Couch
# 		collected 10 episodes
# Querying ... show: DIY Sportsman - Sportsmen's Nation
# 		collected 50 episodes
# Querying ... show: Slim Sports Talks
# 		collected 10 episodes
# Querying ... show: Talking Sport
# 		collected 50 episodes
# Querying ... show: Culture and Sport
# 		collected 10 episodes
# Querying ... show: Sport Up Side
# 		collected 10 episodes
# Querying ... show: Play Sport Victim
# 		collected 10 episodes
# Querying ... show: Mac on sports podcast
# 		collected 50 episodes
# Querying ... show: MSU Sports Zone
# 		collected 50 episodes
# Querying ... show: SportingDog Adventures PodCast
# 		collected 50 episodes
# Querying ... show: Run Sport Club
# 		collected 10 episodes
# Querying ... show: On The Sporting Couch: Lawrence
# 		collected 10 episodes
# Querying ... show: Sportscast
# 		collected 18 episodes
# Querying ... show: Tailgater Sports
# 		collected 50 episodes
# Querying ... show: SCC: Sports Cards Culture
# 		collected 31 episodes
# Querying ... show: The Sporting KC Show
# 		collected 50 episodes
# Querying ... show: Sport RCT
# 		collected 10 episodes
# Querying ... show: On The Sporting Couch: Lawrence
# 		collected 10 episodes
# Querying ... show: The Ultimate Top 10's of Sport
# 		collected 10 episodes
# Querying ... show: Bruins On 98.5 The Sports Hub
# 		collected 50 episodes
# Querying ... show: On The Sporting Couch: Lawrence
# 		collected 10 episodes
# Querying ... show: Cian On Sport
# 		collected 15 episodes
# Querying ... show: Bruins On 98.5 The Sports Hub
# 		collected 50 episodes
# Querying ... show: Florida Sportsman Action Spotter Podcast
# 		collected 50 episodes
# Querying ... show: Foil Sports
# 		collected 6 episodes
# Querying ... show: 410 Sports Talk
# 		collected 50 episodes
# Querying ... show: Buckeye Sportsman
# 		collected 50 episodes
# Querying ... show: Sports Hub Sidelines Podcast
# 		collected 50 episodes
# Querying ... show: Playoff Recap podc sport
# 		collected 10 episodes
# Querying ... show: Touchline Sports - Basketball, Boxing and Formula 1
# 		collected 50 episodes
# Querying ... show: The Sports Agent Secrets Podcast
# 		collected 44 episodes
# Querying ... show: AMSSM Sports Medcasts
# 		collected 28 episodes
# Querying ... show: 412 Sports Talk
# 		collected 39 episodes
# Querying ... show: That DAM Sports Podcast
# 		collected 3 episodes
# Querying ... show: The Walder Sportscast
# 		collected 49 episodes
# Querying ... show: College Sports: Follow The Money
# 		collected 3 episodes
# Querying ... show: Sportstar Podcast
# 		collected 3 episodes
# Querying ... show: 939 Sports
# 		collected 50 episodes
# Querying ... show: Reaction Time Sports
# 		collected 50 episodes
# Querying ... show: Go-Time Sports
# 		collected 5 episodes
# Querying ... show: Learn Pod Culture
# 		collected 10 episodes
# Querying ... show: Culture Gabfest
# 		collected 50 episodes
# Querying ... show: The Pop Culture Show
# 		collected 50 episodes
# Querying ... show: The CULTure
# 		collected 21 episodes
# Querying ... show: Content Culture
# 		collected 12 episodes
# Querying ... show: Pop Culture Role Call
# 		collected 50 episodes
# Querying ... show: Veterans of Culture Wars
# 		collected 30 episodes
# Querying ... show: Celebrity Land - Celeb News, Pop Culture & Britney Spears
# 		collected 50 episodes
# Querying ... show: King & Culture
# 		collected 14 episodes
# Querying ... show: Culture File
# 		collected 50 episodes
# Querying ... show: Cornhole Culture Podcast
# 		collected 16 episodes
# Querying ... show: Changing the Culture
# 		collected 50 episodes
# Querying ... show: Basically Pop Culture
# 		collected 3 episodes
# Querying ... show: Cultural Competence
# 		collected 12 episodes
# Querying ... show: Hop Culture
# 		collected 31 episodes
# Querying ... show: Culture Happens
# 		collected 16 episodes
# Querying ... show: Cars & Culture with Jason Stein
# 		collected 9 episodes
# Querying ... show: Men of Culture
# 		collected 6 episodes
# Querying ... show: Tennis Culture
# 		collected 5 episodes
# Querying ... show: Christ and Culture
# 		collected 40 episodes
# Querying ... show: Shaping The Culture
# 		collected 50 episodes
# Querying ... show: The Culture of Things
# 		collected 50 episodes
# Querying ... show: ABCD (American Born Cultured Desi)
# 		collected 4 episodes
# Querying ... show: BARBER CULTURE
# 		collected 9 episodes
# Querying ... show: Pulp Culture
# 		collected 8 episodes
# Querying ... show: Prime Culture Podcast
# 		collected 37 episodes
# Querying ... show: The Cultural Redemptive
# 		collected 35 episodes
# Querying ... show: Championship Culture
# 		collected 50 episodes
# Querying ... show: Heathen Culture
# 		collected 40 episodes
# Querying ... show: The Fan Culture podcast
# 		collected 29 episodes
# Querying ... show: The Indigenous Cultural Evolutionist
# 		collected 20 episodes
# Querying ... show: De Gudde Podcast: culture, clubbing and more
# 		collected 3 episodes
# Querying ... show: The Culture Shift W/ Brian Brennt
# 		collected 24 episodes
# Querying ... show: Climate Crisis Culture
# 		collected 6 episodes
# Querying ... show: OUR CULTURE INCHOATE
# 		collected 50 episodes
# Querying ... show: The Culture Podcast
# 		collected 13 episodes
# Querying ... show: Hypernasality: A podcast about Speech Therapy and Pop Culture
# 		collected 14 episodes
# Querying ... show: FSForum-Cultural and Social Innovation
# 		collected 31 episodes
# Querying ... show: Movie Culture
# 		collected 24 episodes
# Querying ... show: Pop Culturing My Best Friend
# 		collected 16 episodes
# Querying ... show: Pop Culture Retrorama Podcast – Pop Culture Retrorama
# 		collected 18 episodes
# Querying ... show: Finance & Culture
# 		collected 7 episodes
# Querying ... show: What's Poppin in Pop Culture
# 		collected 7 episodes
# Querying ... show: The Fan Culture podcast
# 		collected 29 episodes
# Querying ... show: The Indigenous Cultural Evolutionist
# 		collected 20 episodes
# Querying ... show: De Gudde Podcast: culture, clubbing and more
# 		collected 3 episodes
# Querying ... show: Star Wars Culture
# 		collected 25 episodes
# Querying ... show: Outside The Culture
# 		collected 12 episodes
# Querying ... show: Sustainable Culture Podcast
# 		collected 20 episodes
# Querying ... show: Saturday Frights Podcast – Pop Culture Retrorama
# 		collected 32 episodes
# Querying ... show: Third Culture Podcast
# 		collected 7 episodes
# Querying ... show: The Culture Bar
# 		collected 19 episodes
# Querying ... show: The Lavendaire Lifestyle
# 		collected 50 episodes
# Querying ... show: ADHD Friendly Lifestyle
# 		collected 18 episodes
# Querying ... show: TED Talks Daily
# 		collected 50 episodes
# Querying ... show: The SuperHero Lifestyle Show
# 		collected 50 episodes
# Querying ... show: Our Lifestyle Podcast (OLP)
# 		collected 50 episodes
# Querying ... show: EXECUTIVE PROTECTION LIFESTYLE
# 		collected 50 episodes
# Querying ... show: Costa Rica Pura Vida Lifestyle Podcast
# Max Retries reached
# http status: 429, code:-1 - /v1/shows/5us0sMPtcjkKuFL4kNHa08/episodes/?limit=50&offset=0&market=TH:
#  Max Retries, reason: too many 500 error responses
# skipped : 5us0sMPtcjkKuFL4kNHa08, Costa Rica Pura Vida Lifestyle Podcast
# 		collected 50 episodes
# Querying ... show: The OT Lifestyle Movement
# 		collected 45 episodes
# Querying ... show: Ronak Shah Show | Books | Lifestyle
# 		collected 50 episodes
# Querying ... show: The Barbell Lifestyle Podcast
# 		collected 37 episodes
# Querying ... show: My Lifestyle Academy Podcast
# 		collected 50 episodes
# Querying ... show: Lifestyle U Podcast
# 		collected 18 episodes
# Querying ... show: RV Lifestyle Expert
# 		collected 30 episodes
# Querying ... show: Health Hero Show: The official Chemical Free Body Lifestyle Podcast
# 		collected 50 episodes
# Querying ... show: The Baller Lifestyle Podcast
# 		collected 50 episodes
# Querying ... show: The Black n Kinky Lifestyle: A Swinger's Podcast
# 		collected 50 episodes
# Querying ... show: Lifestyle Leap
# 		collected 8 episodes
# Querying ... show: Ladies Lifestyle Academy
# 		collected 11 episodes
# Querying ... show: Hotmomz Lifestyle Podcast by Casey Shipp
# 		collected 50 episodes
# Querying ... show: The association of eating habits and lifestyle
# 		collected 10 episodes
# Querying ... show: The Hiking Lifestyle with Your Adventure Coach
# 		collected 15 episodes
# Querying ... show: Space Trash: Lifestyles of the Rich and Uranus
# 		collected 50 episodes
# Querying ... show: Author Lifestyle Podcast
# 		collected 50 episodes
# Querying ... show: Nashville Lifestyles: The Podcast
# 		collected 50 episodes
# Querying ... show: Further Your Lifestyle
# 		collected 23 episodes
# Querying ... show: The Lifestyle Movement Podcast
# 		collected 15 episodes
# Querying ... show: Lofty Lifestyles Podcast
# 		collected 9 episodes
# Querying ... show: Legends & Lifestyles
# 		collected 33 episodes
# Querying ... show: The Andre Lifestyle
# 		collected 25 episodes
# Querying ... show: Beyond Overeating by Wholesome Lifestyle Project
# 		collected 38 episodes
# Querying ... show: Alba Lifestyle Real Talk
# 		collected 11 episodes
# Querying ... show: Lifestyle Practice Builders
# 		collected 50 episodes
# Querying ... show: The Low Carb Lifestyle Podcast
# 		collected 16 episodes
# Querying ... show: Lifestyle by Real Estate Podcast
# 		collected 32 episodes
# Querying ... show: The EVolved Lifestyle
# 		collected 16 episodes
# Querying ... show: Lifestyle Entrepreneurship
# 		collected 50 episodes
# Querying ... show: Exit 12 Home Brew & Craft Beer Lifestyle Podcast
# 		collected 50 episodes
# Querying ... show: The Lifestyle Flipper Show
# 		collected 11 episodes
# Querying ... show: Premium Lifestyle Clubs
# 		collected 8 episodes
# Querying ... show: Dieta, planeta, lifestyle - Kasia Rećko
# 		collected 7 episodes
# Querying ... show: Getufit with Irene- Helping you lead a healthy lifestyle.
# 		collected 50 episodes
# Querying ... show: The Lifestyle Mosaic
# 		collected 25 episodes
# Querying ... show: Wellness Lifestyle Podcast
# 		collected 9 episodes
# Querying ... show: Lemonade Lifestyle Automotive Podcast
# 		collected 14 episodes
# Querying ... show: The Championship Lifestyle Podcast
# 		collected 50 episodes
# Querying ... show: The Tropical MBA Podcast - Entrepreneurship, Travel, and Lifestyle
# 		collected 50 episodes
# Querying ... show: Lifestyle Philosophies with Tony Bruno
# 		collected 14 episodes
# Querying ... show: The Recovery Lifestyle™
# 		collected 13 episodes
# Querying ... show: Laptop Lifestyle Lawyer
# 		collected 16 episodes
# Querying ... show: For All Drinks: Delicious Non-Alcoholic Beverages for Leading a Fun, Healthy, and Inclusive Lifestyle
# 		collected 27 episodes
# Querying ... show: JOST SAUER: The Lifestyle Medicine Man
# 		collected 12 episodes
# Querying ... show: Fresh Lifestyle Fitness
# 		collected 25 episodes
# Querying ... show: RSVP Talk Lifestyle
# 		collected 21 episodes
# Querying ... show: Business Industry
# 		collected 4 episodes
# Querying ... show: Business Wars
# 		collected 50 episodes
# Querying ... show: Business Casual Podcast
# 		collected 10 episodes
# Querying ... show: Business Daily
# 		collected 50 episodes
# Querying ... show: Invading Pigs, Monkey Business
# 		collected 10 episodes
# Querying ... show: Business English Pod (MP3 Audio Only)
# 		collected 50 episodes
# Querying ... show: TED Business podcasts
# 		collected 10 episodes
# Querying ... show: TED Business
# 		collected 50 episodes
# Querying ... show: Business English Skills 360
# 		collected 50 episodes
# Querying ... show: Business Research for Business Leaders
# 		collected 10 episodes
# Querying ... show: Masters in Business
# 		collected 50 episodes
# Querying ... show: It generally takes a few business days
# 		collected 10 episodes
# Querying ... show: Business Wars Daily
# 		collected 50 episodes
# Querying ... show: Business Movers
# 		collected 34 episodes
# Querying ... show: 5 Minute Business Book Summaries
# 		collected 22 episodes
# Querying ... show: Business Breakdowns
# 		collected 22 episodes
# Querying ... show: World Business Report
# 		collected 46 episodes
# Querying ... show: The Business of Fashion Podcast
# 		collected 50 episodes
# Querying ... show: Business Facts
# 		collected 20 episodes
# Querying ... show: Great Women of Business
# 		collected 13 episodes
# Querying ... show: The Ian King Business Podcast
# 		collected 50 episodes
# Querying ... show: The Art of Business English
# 		collected 50 episodes
# Querying ... show: Harvard Business Case Studies / Case Study On Management, MBA, HR, Marketing, SCM, Operations, AI,
# 		collected 6 episodes
# Querying ... show: Let's Talk Business English.
# 		collected 20 episodes
# Querying ... show: Masters in Business Podcast
# 		collected 10 episodes
# Querying ... show: Tow Business Podcast
# 		collected 50 episodes
# Querying ... show: Start A Handyman Business
# 		collected 10 episodes
# Querying ... show: Businessfika
# 		collected 5 episodes
# Querying ... show: The Fangirl Business
# 		collected 50 episodes
# Querying ... show: The Family Business with The Alessis
# 		collected 16 episodes
# Querying ... show: Unfinished Business
# 		collected 13 episodes
# Querying ... show: Start A Handyman Business
# 		collected 10 episodes
# Querying ... show: Business Tao with George Kao
# 		collected 50 episodes
# Querying ... show: Alloy Personal Training Business
# 		collected 50 episodes
# Querying ... show: The Fangirl Business
# 		collected 50 episodes
# Querying ... show: The Mobile Notary Business Expert Secret Show
# 		collected 34 episodes
# Querying ... show: Tipsy Business
# 		collected 50 episodes
# Querying ... show: Bella In Your Business: Pet Industry Business Podcast
# 		collected 50 episodes
# Querying ... show: COWGIRL BUSINESS
# 		collected 8 episodes
# Querying ... show: The Business Class
# 		collected 23 episodes
# Querying ... show: THE STEFANIE GASS SHOW - Get Clarity, Online Business, Work From Home, WAHM, Passive Income
# 		collected 50 episodes
# Querying ... show: Nitrafit Business - None Of Your Business
# 		collected 9 episodes
# Querying ... show: Calgary Business Podcast
# 		collected 50 episodes
# Querying ... show: Fusion Presents: The Business Lounge
# 		collected 20 episodes
# Querying ... show: The Better Business Podcast
# 		collected 13 episodes
# Querying ... show: Bowties and Business Podcast
# 		collected 50 episodes
# Querying ... show: Business Hangout with Rajiv Talreja
# 		collected 50 episodes
# Querying ... show: Master Builders Elevate: Building a Better Business
# 		collected 48 episodes
# Querying ... show: People Business w/ O'Brien McMahon
# 		collected 50 episodes
# Querying ... show: Small Business Collective Podcast
# 		collected 8 episodes
# Querying ... show: Sports Business Updates
# 		collected 20 episodes
# Querying ... show: No Bull Business And Brews
# 		collected 26 episodes

# %%
total_df.shape
# Out:
# (14127, 5)

# %%
mask = total_df.duplicated(subset=['description'], keep=False)
mask.sum()
# Out:
# 1738

# %%
e=0
for i in total_df[mask].description:
    print(i)
    e+=1
    if e == 10:break
# Out:
#   Charles Max Wood discusses several opportunities that came his way early in his podcasting career and other opportunities that have come to other people after only a couple of podcast episodes. He explains why that happens and how you can use this to create more influence as a developer.    Panel      Charles Max Wood
#   Charles Max Wood discusses several opportunities that came his way early in his podcasting career and other opportunities that have come to other people after only a couple of podcast episodes. He explains why that happens and how you can use this to create more influence as a developer.    Panel      Charles Max Wood
#   Chuck outlines how he's used his podcasts to find mentors to continue his learning journey over 12 years of podcasting. Some mentors have been long lived relationships while others have lasted only a few months or even days. This episode shares Chuck's experience learning from the top people in the development community as a programmer and podcaster.    Panel      Charles Max Wood
#   Chuck outlines how he's used his podcasts to find mentors to continue his learning journey over 12 years of podcasting. Some mentors have been long lived relationships while others have lasted only a few months or even days. This episode shares Chuck's experience learning from the top people in the development community as a programmer and podcaster.    Panel      Charles Max Wood
# John-Daniel Trask, founder and CEO of Raygun, talks about his experience building a monitoring company and about how to measure the speed and quality of your code.
# John-Daniel Trask, founder and CEO of Raygun, talks about his experience building a monitoring company and about how to measure the speed and quality of your code.
#
# Kippy and Foley are back with a hot episode full of listener questions! The boys talk the best way to cook a hot dog, Tubby Time, and stealing from the grocery store.  ---   Support this podcast: https://anchor.fm/hilmanrega567/support
# Kippy and Foley are back with a hot episode full of listener questions! The boys talk the best way to cook a hot dog, Tubby Time, and stealing from the grocery store.  ---   Support this podcast: https://anchor.fm/hilmanrega567/support
# Kippy and Foley are back with a hot episode full of listener questions! The boys talk the best way to cook a hot dog, Tubby Time, and stealing from the grocery store.  ---   Support this podcast: https://anchor.fm/hilmanrega567/support

# %%
total_df.to_csv('total_df.csv', index=False)

# %%
pd.read_csv('total_df.csv')
# Out:
#                         ep_id  ...             label
# 0      2QwU0zzueDDoi0fN3Kf0HR  ...  machine learning
# 1      1ir7MrWUBwUI6AE7Na5diX  ...  machine learning
# 2      1ACeGKFk4syDdcRuuuSZP7  ...  machine learning
# 3      1vuc4azX8Mb0sl0lKOmxZi  ...  machine learning
# 4      6DrRmtpKKpH3yYJ6yPoMR2  ...  machine learning
# ...                       ...  ...               ...
# 14122  27NZuo9cAYjf5kOzUTjeIk  ...          business
# 14123  25UAT6zU2TdtgkspfTacPt  ...          business
# 14124  6wNFI4ONRSFzheWcIV2AaK  ...          business
# 14125  3fbCPaqqj4iguoqayDowfW  ...          business
# 14126  4ukmNvsXXObEcOK5YHtcLl  ...          business
#
# [14127 rows x 5 columns]
